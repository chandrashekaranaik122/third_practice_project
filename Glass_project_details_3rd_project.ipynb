# %% [markdown]
# Glass Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# import all the nessasary lybraries

# %%
df=pd.read_csv('Glass_csv.file')
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %% [markdown]
# Loading the dataset from my jupyter notebook as veriable df
#
# the dataset has no columns names

# %%
col_names=['Id_number','RI(refractive_index)','Na(Sodium)','Mg(Magnesium)','Al(Aluminum)','Si(silicon)','K(potassium)','Ca(Calcium)','Ba(Barium)','Fe(Iron)','Type_of_glass']

# %% [markdown]
# since the dataset has no columns name thats the reason manually i am giving the column names

# %%
df=pd.read_csv('Glass_csv.file',names=col_names)
df
# Out:
#      Id_number  RI(refractive_index)  Na(Sodium)  Mg(Magnesium)  Al(Aluminum)  \
# 0            1               1.52101       13.64           4.49          1.10
# 1            2               1.51761       13.89           3.60          1.36
# 2            3               1.51618       13.53           3.55          1.54
# 3            4               1.51766       13.21           3.69          1.29
# 4            5               1.51742       13.27           3.62          1.24
# ..         ...                   ...         ...            ...           ...
# 209        210               1.51623       14.14           0.00          2.88
# 210        211               1.51685       14.92           0.00          1.99
# 211        212               1.52065       14.36           0.00          2.02
# 212        213               1.51651       14.38           0.00          1.94
# 213        214               1.51711       14.23           0.00          2.08
#
# ...

# %% [markdown]
# now we can see that all the columns has names

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id_number             214 non-null    int64
#  1   RI(refractive_index)  214 non-null    float64
#  2   Na(Sodium)            214 non-null    float64
#  3   Mg(Magnesium)         214 non-null    float64
#  4   Al(Aluminum)          214 non-null    float64
#  5   Si(silicon)           214 non-null    float64
#  6   K(potassium)          214 non-null    float64
#  7   Ca(Calcium)           214 non-null    float64
#  8   Ba(Barium)            214 non-null    float64
#  9   Fe(Iron)              214 non-null    float64
#  10  Type_of_glass         214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %% [markdown]
# there 214 rows and 11 columns present the dataset and using memory of 18.5kb

# %%
df.dtypes
# Out:
# Id_number                 int64
# RI(refractive_index)    float64
# Na(Sodium)              float64
# Mg(Magnesium)           float64
# Al(Aluminum)            float64
# Si(silicon)             float64
# K(potassium)            float64
# Ca(Calcium)             float64
# Ba(Barium)              float64
# Fe(Iron)                float64
# Type_of_glass             int64
# dtype: object

# %% [markdown]
# 2 types of data is present in the dataset , they are integers and float values ...
#
# only 2 columns has integer type and rest are float datatype

# %%
df.columns
# Out:
# Index(['Id_number', 'RI(refractive_index)', 'Na(Sodium)', 'Mg(Magnesium)',
#        'Al(Aluminum)', 'Si(silicon)', 'K(potassium)', 'Ca(Calcium)',
#        'Ba(Barium)', 'Fe(Iron)', 'Type_of_glass'],
#       dtype='object')

# %% [markdown]
# we can all the columns names here

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 1      1
# 135    1
# 137    1
# 138    1
# 139    1
#       ..
# 75     1
# 76     1
# 77     1
# 78     1
# 214    1
# Name: Id_number, Length: 214, dtype: int64
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: RI(refractive_index), Length: 178, dtype: int64
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Na(Sodium), Length: 142, dtype: int64
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Mg(Magnesium), Length: 94, dtype: int64
# 1.54    8
# 1.19    6
# 1.43    5
# 1.29    5
# 1.23    5
#        ..
# 1.08    1
# 1.64    1
# 1.61    1
# 1.07    1
# 1.94    1
# Name: Al(Aluminum), Length: 118, dtype: int64
# 72.86    4
# 72.99    4
# 73.10    4
# 73.28    4
# ...

# %% [markdown]
# checking for the value counts , all the rows has values there is no columns has null values

# %%
for i in df.columns:
    print(i,'-',df[i].nunique())
# Out:
# Id_number - 214
# RI(refractive_index) - 178
# Na(Sodium) - 142
# Mg(Magnesium) - 94
# Al(Aluminum) - 118
# Si(silicon) - 133
# K(potassium) - 65
# Ca(Calcium) - 143
# Ba(Barium) - 34
# Fe(Iron) - 32
# Type_of_glass - 6

# %% [markdown]
# unique values in the each columns , refractive_index column and calcium column has more unique values

# %%
df.isnull().sum()
# Out:
# Id_number               0
# RI(refractive_index)    0
# Na(Sodium)              0
# Mg(Magnesium)           0
# Al(Aluminum)            0
# Si(silicon)             0
# K(potassium)            0
# Ca(Calcium)             0
# Ba(Barium)              0
# Fe(Iron)                0
# Type_of_glass           0
# dtype: int64

# %% [markdown]
# there is null values present in the dataset

# %%
df.describe()
# Out:
#         Id_number  RI(refractive_index)  Na(Sodium)  Mg(Magnesium)  \
# count  214.000000            214.000000  214.000000     214.000000
# mean   107.500000              1.518365   13.407850       2.684533
# std     61.920648              0.003037    0.816604       1.442408
# min      1.000000              1.511150   10.730000       0.000000
# 25%     54.250000              1.516522   12.907500       2.115000
# 50%    107.500000              1.517680   13.300000       3.480000
# 75%    160.750000              1.519157   13.825000       3.600000
# max    214.000000              1.533930   17.380000       4.490000
#
#        Al(Aluminum)  Si(silicon)  K(potassium)  Ca(Calcium)  Ba(Barium)  \
# count    214.000000   214.000000    214.000000   214.000000  214.000000
# mean       1.444907    72.650935      0.497056     8.956963    0.175047
# std        0.499270     0.774546      0.652192     1.423153    0.497219
# min        0.290000    69.810000      0.000000     5.430000    0.000000
# ...

# %% [markdown]
# Statistical analysis for the dataset
#
# * Each column has 214 rows and with no null values
#
# * the median is greater than the mean in mejority of columns , we can clearly say thet left skewed data present with outliers
#
# * The columns Aluminum,potassium and calcium has outliers because the 75th percentile and max has huge difference in the value
#
# * we need to remove some outliers from the dataset for better prediction

# %% [markdown]
# Univeriate Analysis

# %%
sns.countplot(df['Type_of_glass'])
# Out:
# <AxesSubplot:xlabel='Type_of_glass', ylabel='count'>

# %% [markdown]
# checking for type of glass as mentioned in the problem statement
# the numbers represents the which type of Glass
#
# •	1- building_windows_float_processed
#
# •	2- building_windows_non_float_processed
#
# •	3- vehicle_windows_float_processed
#
# •	4- vehicle_windows_non_float_processed (none in this database)
#
# •	5- containers
#
# •	6- tableware
#
# •	7- headlamps

# %%
sns.histplot(df['RI(refractive_index)'])
# Out:
# <AxesSubplot:xlabel='RI(refractive_index)', ylabel='Count'>

# %% [markdown]
# the mejority of the data is present in between 1.515 to 1.525 refractive index

# %%
sns.histplot(df['Mg(Magnesium)'])
# Out:
# <AxesSubplot:xlabel='Mg(Magnesium)', ylabel='Count'>

# %% [markdown]
# the data spread with a range of 0 to 4

# %%
sns.histplot(df['K(potassium)'])
# Out:
# <AxesSubplot:xlabel='K(potassium)', ylabel='Count'>

# %% [markdown]
# some data spread is clearly visible in potassium column

# %% [markdown]
# Bivariate Analysis

# %%
sns.scatterplot(data=df,x='RI(refractive_index)',y='Type_of_glass')
# Out:
# <AxesSubplot:xlabel='RI(refractive_index)', ylabel='Type_of_glass'>

# %% [markdown]
# the refractive index increses the glass is suitable to building window non floatables

# %%
sns.scatterplot(data=df,x='Ca(Calcium)',y='K(potassium)')
# Out:
# <AxesSubplot:xlabel='Ca(Calcium)', ylabel='K(potassium)'>

# %% [markdown]
# calcium and potassium columns indirectly proportinal to each other

# %%
sns.pairplot(data=df)

# %% [markdown]
# with the help of pairplot we can see the all reletion of columns with respect to the each column

# %%
df.corr()
# Out:
#                       Id_number  RI(refractive_index)  Na(Sodium)  \
# Id_number              1.000000             -0.072209    0.375722
# RI(refractive_index)  -0.072209              1.000000   -0.191885
# Na(Sodium)             0.375722             -0.191885    1.000000
# Mg(Magnesium)         -0.650328             -0.122274   -0.273732
# Al(Aluminum)           0.490113             -0.407326    0.156794
# Si(silicon)            0.061232             -0.542052   -0.069809
# K(potassium)           0.003149             -0.289833   -0.266087
# Ca(Calcium)            0.090800              0.810403   -0.275442
# Ba(Barium)             0.451001             -0.000386    0.326603
# Fe(Iron)              -0.072794              0.143010   -0.241346
# Type_of_glass          0.877357             -0.164237    0.502898
#
#                       Mg(Magnesium)  Al(Aluminum)  Si(silicon)  K(potassium)  \
# Id_number                 -0.650328      0.490113     0.061232      0.003149
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linecolor='black',linewidth=0.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# checking for the co reletion of the each columns
# * Magnesium columns is highly negative co reletion with target
#
# * refractive index and iron columnns has little negative co reletion
#
# * Sodium,Aluminium and Barium  columns are highly positive co reletion with the target

# %%
plt.figure(figsize=(15,15),facecolor='y')

p=1

for i in df.columns:
    if p<20:
        plt.subplot(5,3,p)
        sns.boxplot(data=df[i],palette='muted')
        plt.xlabel('density')
        plt.ylabel(i)
    p+=1
    
plt.show()

# %% [markdown]
# checking for the Outliers
#
# with the help of Boxplot here checking for the outliers in the dataset...
#
# some of the has maximum outliers Calsium , Aluminium and Barium columns has maximum outliers , follwed by silicon and Iron columns
#
# we need to remove the outliers

# %% [markdown]
# Outliers Removal

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#      Id_number  RI(refractive_index)  Na(Sodium)  Mg(Magnesium)  Al(Aluminum)  \
# 0     1.723976              0.872868    0.284953       1.254639      0.692442
# 1     1.707788              0.249333    0.591817       0.636168      0.170460
# 2     1.691601              0.721318    0.149933       0.601422      0.190912
# 3     1.675413              0.232831    0.242853       0.698710      0.310994
# 4     1.659226              0.312045    0.169205       0.650066      0.411375
# ..         ...                   ...         ...            ...           ...
# 209   1.659226              0.704815    0.898681       1.865511      2.881125
# 210   1.675413              0.500178    1.856097       1.865511      1.094342
# 211   1.691601              0.754046    1.168721       1.865511      1.154570
# 212   1.707788              0.612399    1.193270       1.865511      0.993960
# 213   1.723976              0.414363    1.009152       1.865511      1.275028
#
# ...

# %% [markdown]
# using the ZSCORE method to remove the outliers

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([105, 106, 106, 106, 106, 106, 107, 107, 107, 110, 111, 112, 112,
#        131, 145, 162, 163, 163, 163, 171, 171, 172, 172, 174, 184, 184,
#        188, 189, 201, 201, 203, 207, 213], dtype=int64), array([7, 1, 2, 5, 7, 8, 1, 5, 7, 7, 7, 1, 7, 7, 9, 9, 4, 5, 8, 4, 6, 4,
#        6, 9, 2, 5, 5, 8, 5, 6, 8, 8, 8], dtype=int64))

# %% [markdown]
# setting the threshold to 3 because 99%of present upto 3 standard deviations

# %%
z.iloc[105][7]
# Out:
# 3.01659640155971

# %%
z.iloc[213][8]
# Out:
# 3.0136773864449404

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#      Id_number  RI(refractive_index)  Na(Sodium)  Mg(Magnesium)  Al(Aluminum)  \
# 0            1               1.52101       13.64           4.49          1.10
# 1            2               1.51761       13.89           3.60          1.36
# 2            3               1.51618       13.53           3.55          1.54
# 3            4               1.51766       13.21           3.69          1.29
# 4            5               1.51742       13.27           3.62          1.24
# ..         ...                   ...         ...            ...           ...
# 208        209               1.51640       14.37           0.00          2.74
# 209        210               1.51623       14.14           0.00          2.88
# 210        211               1.51685       14.92           0.00          1.99
# 211        212               1.52065       14.36           0.00          2.02
# 212        213               1.51651       14.38           0.00          1.94
#
# ...

# %% [markdown]
# Removing the outliers and saving the data in the new dataset df1

# %%
print(df.shape)
print(df1.shape)
# Out:
# (214, 11)
# (194, 11)

# %% [markdown]
# we can see that df1 has less columns compared to df , so the outliers are removed

# %%
df1=df1.drop('Ba(Barium)',axis=1)

# %% [markdown]
# the Barium column has max outliers so removing the column from the dataset

# %%
df1
# Out:
#      Id_number  RI(refractive_index)  Na(Sodium)  Mg(Magnesium)  Al(Aluminum)  \
# 0            1               1.52101       13.64           4.49          1.10
# 1            2               1.51761       13.89           3.60          1.36
# 2            3               1.51618       13.53           3.55          1.54
# 3            4               1.51766       13.21           3.69          1.29
# 4            5               1.51742       13.27           3.62          1.24
# ..         ...                   ...         ...            ...           ...
# 208        209               1.51640       14.37           0.00          2.74
# 209        210               1.51623       14.14           0.00          2.88
# 210        211               1.51685       14.92           0.00          1.99
# 211        212               1.52065       14.36           0.00          2.02
# 212        213               1.51651       14.38           0.00          1.94
#
# ...

# %%
plt.figure(figsize=(15,15))

p=1

for i in df1.columns:
    if p<18:
        plt.subplot(5,3,p)
        sns.distplot(df1[i])
        plt.xlabel('density')
        plt.ylabel(i)
        
    p+=1
plt.show()

# %% [markdown]
# using the distribution plot to find the skewness of the dataset...
# some columns has skewness like Magnesium

# %%
df1.skew()
# Out:
# Id_number               0.107537
# RI(refractive_index)    0.952733
# Na(Sodium)              0.371482
# Mg(Magnesium)          -1.528849
# Al(Aluminum)            0.658259
# Si(silicon)            -0.425450
# K(potassium)            0.303175
# Ca(Calcium)             1.077962
# Fe(Iron)                1.486479
# Type_of_glass           1.284007
# dtype: float64

# %%
df1['Mg(Magnesium)']=np.cbrt(df1['Mg(Magnesium)'])

# %% [markdown]
# using cube root method to remove the skewness from the magnesium column

# %%
df1.skew()
# Out:
# Id_number               0.107537
# RI(refractive_index)    0.952733
# Na(Sodium)              0.371482
# Mg(Magnesium)          -1.899050
# Al(Aluminum)            0.658259
# Si(silicon)            -0.425450
# K(potassium)            0.303175
# Ca(Calcium)             1.077962
# Fe(Iron)                1.486479
# Type_of_glass           1.284007
# dtype: float64

# %%
plt.figure(figsize=(15,15))

p=1

for i in df1.columns:
    if p<18:
        plt.subplot(5,3,p)
        sns.distplot(df1[i])
        plt.xlabel('density')
        plt.ylabel(i)
        
    p+=1
plt.show()

# %%
x=df1.iloc[:,:-1]
x
# Out:
#      Id_number  RI(refractive_index)  Na(Sodium)  Mg(Magnesium)  Al(Aluminum)  \
# 0            1               1.52101       13.64       1.649740          1.10
# 1            2               1.51761       13.89       1.532619          1.36
# 2            3               1.51618       13.53       1.525490          1.54
# 3            4               1.51766       13.21       1.545286          1.29
# 4            5               1.51742       13.27       1.535452          1.24
# ..         ...                   ...         ...            ...           ...
# 208        209               1.51640       14.37       0.000000          2.74
# 209        210               1.51623       14.14       0.000000          2.88
# 210        211               1.51685       14.92       0.000000          1.99
# 211        212               1.52065       14.36       0.000000          2.02
# 212        213               1.51651       14.38       0.000000          1.94
#
# ...

# %% [markdown]
# Separating the x columns from the dataset

# %%
y=df1.iloc[:,-1]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 208    7
# 209    7
# 210    7
# 211    7
# 212    7
# Name: Type_of_glass, Length: 194, dtype: int64

# %% [markdown]
# separated the target variable

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#      Id_number  RI(refractive_index)  Na(Sodium)  Mg(Magnesium)  Al(Aluminum)  \
# 0    -1.649313              1.291781    0.332127       0.700169     -0.729105
# 1    -1.633019             -0.197832    0.704398       0.481196     -0.141722
# 2    -1.616725             -0.824346    0.168328       0.467868      0.264928
# 3    -1.600431             -0.175926   -0.308179       0.504878     -0.299864
# 4    -1.584137             -0.281075   -0.218834       0.486492     -0.412822
# ..         ...                   ...         ...            ...           ...
# 189   1.739854             -0.727959    1.419158      -2.384242      2.975928
# 190   1.756148             -0.802440    1.076668      -2.384242      3.292211
# 191   1.772442             -0.530805    2.238153      -2.384242      1.281553
# 192   1.788737              1.134057    1.404267      -2.384242      1.349328
# 193   1.805031             -0.679766    1.434048      -2.384242      1.168595
#
# ...

# %% [markdown]
# using the standard scaler to stadardzise the values with mean zero

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif['VIF Features']=x.columns
vif
# Out:
#    VIF Values          VIF Features
# 0    1.876207             Id_number
# 1    4.998125  RI(refractive_index)
# 2    7.097506            Na(Sodium)
# 3   10.433571         Mg(Magnesium)
# 4    3.827398          Al(Aluminum)
# 5    5.262052           Si(silicon)
# 6    3.384510          K(potassium)
# 7    6.563117           Ca(Calcium)
# 8    1.063622              Fe(Iron)

# %% [markdown]
# checking for the multicolinearity of the each column , Magnesium column has high vif value

# %%
x=x.drop(['Mg(Magnesium)'],axis=1)

# %% [markdown]
# droping the Magnesium column from the dataset because its has high vif value

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif['VIF Features']=x.columns
vif
# Out:
#    VIF Values          VIF Features
# 0    1.861830             Id_number
# 1    4.870083  RI(refractive_index)
# 2    2.997149            Na(Sodium)
# 3    2.085151          Al(Aluminum)
# 4    2.496750           Si(silicon)
# 5    3.027439          K(potassium)
# 6    3.184603           Ca(Calcium)
# 7    1.062237              Fe(Iron)

# %% [markdown]
# now the vif values of every column is lessthan 10

# %%
y.value_counts()
# Out:
# 1    70
# 2    68
# 7    23
# 3    16
# 5     9
# 6     8
# Name: Type_of_glass, dtype: int64

# %% [markdown]
# since the problem is classification problem ...
#
# the target is not having the equal prediction for each type of glass ..
#
# we need eqall number of prediction for each type

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %% [markdown]
# applying the SMOTE method to resample the each predictions

# %%
y.value_counts()
# Out:
# 1    70
# 2    70
# 3    70
# 5    70
# 6    70
# 7    70
# Name: Type_of_glass, dtype: int64

# %% [markdown]
# all the types has eqall number of prediction for each

# %% [markdown]
# Modelling

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# importing classifictions models which needed for the prediction

# %%
maxAccu=0
maxRs=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred=dtc.predict(x_test)
    accu=accuracy_score(y_test,pred)
    if accu>maxAccu:
        maxAccu=accu
        maxRs=i
print('the Best accuracy score is =',maxAccu,'at the random state of =',maxRs)
# Out:
# the Best accuracy score is = 1.0 at the random state of = 3

# %% [markdown]
# checking for the best random state for the predction of my model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRs)

# %% [markdown]
# splitting the model with best accuracry score

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.svm import SVC

# %% [markdown]
# importing all the nessasary models for the best prediction for dataset

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print('Accuracy score',accuracy_score(y_test,predrf)*100)
print('classification report','\n',classification_report(y_test,predrf))
print('confusion matrix','\n',confusion_matrix(y_test,predrf))
# Out:
# Accuracy score 99.20634920634922
# classification report
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        20
#            2       1.00      0.96      0.98        26
#            3       0.96      1.00      0.98        22
#            5       1.00      1.00      1.00        24
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00        23
#
#     accuracy                           0.99       126
#    macro avg       0.99      0.99      0.99       126
# weighted avg       0.99      0.99      0.99       126
#
# confusion matrix
#  [[20  0  0  0  0  0]
#  [ 0 25  1  0  0  0]
#  [ 0  0 22  0  0  0]
#  [ 0  0  0 24  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]

# %% [markdown]
# with RandomForestClassifier the accuracy score is 99.20 and f1 score is 1 , precision also 1

# %%
et=ExtraTreesClassifier()
et.fit(x_train,y_train)
predet=et.predict(x_test)
print('Accuracy Score',accuracy_score(y_test,predet)*100)
print('Classification report','\n',classification_report(y_test,predet))
print('Confusion matrix ','\n',confusion_matrix(y_test,predet))
# Out:
# Accuracy Score 99.20634920634922
# Classification report
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        20
#            2       1.00      0.96      0.98        26
#            3       1.00      1.00      1.00        22
#            5       0.96      1.00      0.98        24
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00        23
#
#     accuracy                           0.99       126
#    macro avg       0.99      0.99      0.99       126
# weighted avg       0.99      0.99      0.99       126
#
# Confusion matrix
#  [[20  0  0  0  0  0]
#  [ 0 25  0  1  0  0]
#  [ 0  0 22  0  0  0]
#  [ 0  0  0 24  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]

# %% [markdown]
# with ExtraTreesClassifier accuracy score is 99.20 and f1 score is 1 , precision is 1

# %%
bg=BaggingClassifier()
bg.fit(x_train,y_train)
predbg=bg.predict(x_test)
print('Accuracy score',accuracy_score(y_test,predbg)*100)
print('classification report','\n',classification_report(y_test,predbg))
print('confusion matrix','\n',confusion_matrix(y_test,predbg))
# Out:
# Accuracy score 100.0
# classification report
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        20
#            2       1.00      1.00      1.00        26
#            3       1.00      1.00      1.00        22
#            5       1.00      1.00      1.00        24
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00        23
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126
#
# confusion matrix
#  [[20  0  0  0  0  0]
#  [ 0 26  0  0  0  0]
#  [ 0  0 22  0  0  0]
#  [ 0  0  0 24  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]

# %% [markdown]
# BaggingClassifier the Accuracy score 100 and all parameters are good with score 1

# %%
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
predad=ad.predict(x_test)
print('Accuracy Score',accuracy_score(y_test,predad)*100)
print('classification report','\n',classification_report(y_test,predad))
print('confusion matrix','\n',confusion_matrix(y_test,predad))
# Out:
# Accuracy Score 60.317460317460316
# classification report
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        20
#            2       0.00      0.00      0.00        26
#            3       0.31      1.00      0.47        22
#            5       0.00      0.00      0.00        24
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00        23
#
#     accuracy                           0.60       126
#    macro avg       0.55      0.67      0.58       126
# weighted avg       0.48      0.60      0.51       126
#
# confusion matrix
#  [[20  0  0  0  0  0]
#  [ 0  0 26  0  0  0]
#  [ 0  0 22  0  0  0]
#  [ 0  0 24  0  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]

# %% [markdown]
# with AdaBoostClassifier the accuracy score 60% only and some of types of glass is not predicting well

# %%
gd=GradientBoostingClassifier()
gd.fit(x_train,y_train)
predgd=gd.predict(x_test)
print('Accuracy score',accuracy_score(y_test,predgd)*100)
print('classification report','\n',classification_report(y_test,predgd))
print('confusion matrix','\n',confusion_matrix(y_test,predgd))
# Out:
# Accuracy score 98.4126984126984
# classification report
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        20
#            2       1.00      0.92      0.96        26
#            3       1.00      1.00      1.00        22
#            5       0.92      1.00      0.96        24
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00        23
#
#     accuracy                           0.98       126
#    macro avg       0.99      0.99      0.99       126
# weighted avg       0.99      0.98      0.98       126
#
# confusion matrix
#  [[20  0  0  0  0  0]
#  [ 0 24  0  2  0  0]
#  [ 0  0 22  0  0  0]
#  [ 0  0  0 24  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]

# %% [markdown]
# with GradientBoostigClassifier the accuracy score is 98.41%

# %%
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print('Accuracy score',accuracy_score(y_test,predsvc)*100)
print('classification report','\n',classification_report(y_test,predsvc))
print('confusion matrix','\n',confusion_matrix(y_test,predsvc))
# Out:
# Accuracy score 96.03174603174604
# classification report
#                precision    recall  f1-score   support
#
#            1       1.00      0.95      0.97        20
#            2       0.92      0.88      0.90        26
#            3       1.00      0.95      0.98        22
#            5       0.96      1.00      0.98        24
#            6       0.92      1.00      0.96        11
#            7       0.96      1.00      0.98        23
#
#     accuracy                           0.96       126
#    macro avg       0.96      0.96      0.96       126
# weighted avg       0.96      0.96      0.96       126
#
# confusion matrix
#  [[19  1  0  0  0  0]
#  [ 0 23  0  1  1  1]
#  [ 0  1 21  0  0  0]
#  [ 0  0  0 24  0  0]
#  [ 0  0  0  0 11  0]
#  [ 0  0  0  0  0 23]]

# %% [markdown]
# with Support vector mission 96%

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# we have check for over fitting and under fitting ,
# i am importing the cross validation score

# %%
print('GradientBoostClassifier')
scoregd=cross_val_score(gd,x,y)
print(scoregd*100)
print('Mean score',scoregd.mean()*100)
print('\n')

print('AdaBoostClassifer')
scoread=cross_val_score(ad,x,y)
print(scoread*100)
print('Mean score',scoread.mean()*100)
print('\n')

print('ExtraTreesClassifier')
scoreet=cross_val_score(et,x,y)
print(scoreet*100)
print('Mean score',scoreet.mean()*100)
print('\n')

print('RandomForestClassifier')
scorerf=cross_val_score(rf,x,y)
print(scorerf*100)
print('Mean score',scorerf.mean()*100)
print('\n')

print('BaggingClassifier')
scorebg=cross_val_score(bg,x,y)
print(scorebg*100)
print('Mean score',scorebg.mean()*100)
print('\n')

print('DecisionTreeClassifier')
scoredtc=cross_val_score(dtc,x,y)
print(scoredtc*100)
print('Mean score',scoredtc.mean()*100)
print('\n')

print('Support vector')
scoresvc=cross_val_score(svc,x,y)
print(scoresvc*100)
print('Mean score',scoresvc.mean()*100)
# Out:
# GradientBoostClassifier
# [ 88.0952381  100.         100.         100.          85.71428571]
# Mean score 94.76190476190476
#
#
# AdaBoostClassifer
# [39.28571429 50.         50.         50.         41.66666667]
# Mean score 46.19047619047619
#
#
# ExtraTreesClassifier
# [ 97.61904762 100.          96.42857143  97.61904762  96.42857143]
# Mean score 97.61904761904762
#
#
# RandomForestClassifier
# [ 92.85714286 100.          97.61904762 100.          91.66666667]
# Mean score 96.42857142857142
#
#
# BaggingClassifier
# [ 88.0952381  100.         100.         100.          85.71428571]
# Mean score 94.76190476190476
#
#
# DecisionTreeClassifier
# [ 89.28571429 100.         100.         100.          85.71428571]
# Mean score 95.0
#
#
# Support vector
# [95.23809524 96.42857143 95.23809524 96.42857143 98.80952381]
# Mean score 96.42857142857142

# %% [markdown]
# after cross validation the best model is ExtraTreesClassifier and accuracy score is 97.61%

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# importing GridSearchCV for hypertuning the model

# %%
parameters={'criterion':['gini','entropy'],
           'random_state':[10,20,100],
           'max_depth':[0,10,20],
           'n_jobs':[-2,-1,1],
           'n_estimators':[50,100,150,200]}

# %% [markdown]
# sending the best parameters to the model

# %%
gscv=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'n_estimators': 150,
#  'n_jobs': -2,
#  'random_state': 10}

# %% [markdown]
# sending the x_train and y_train to the gridsearchcv

# %%
model=ExtraTreesClassifier(criterion='entropy',max_depth=10,n_estimators=150,n_jobs=-2,random_state=10)

# %% [markdown]
# after getting the best parameters , Building the my new model

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('accuracy_score',accuracy_score(y_test,pred)*100)
# Out:
# accuracy_score 100.0

# %% [markdown]
# sending the test data through the model and the best accuracy score

# %%
import pickle
filename='Glass_project'
pickle.dump(model,open(filename,'wb'))

# %% [markdown]
# importing the pickle lybrary to save the model and giving the filename=Glass_project

# %%
new_model=pickle.load(open('Glass_project','rb'))
new_model.score(x_test,y_test)*100
# Out:
# 100.0

# %% [markdown]
# loading saved model from the jupyter notebook which is saved and checking for the accuracy score
